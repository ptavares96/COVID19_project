# %% [markdown]
# # Panorama do COVID-19 no Mundo e no Brasil
# COVID-19 é uma doença infecciosa causada por recém-descoberto coronavírus.
#
# Transmitido principalmente por meio de gotículas provenientes de tosses ou espirros de pessoas infectadas, a gravidade dos sintomas varia muito de pessoa para pessoa.
#
# Fato é, não se sabe muita coisa a respeito do COVID-19. Estudos estão sendo realizados no mundo todo, porém os resultados ainda não são conclusivos e definitivos.
#
# <center><img alt="Colaboratory logo" width="50%" src="https://raw.githubusercontent.com/carlosfab/dsnp2/master/img/covid19.jpg"></center>
#
# Até o presente momento, observa-se que cerca de 80% dos casos confirmados são assintomáticos e rápidos. A maioria das pessoas que se encaixam nesse grupo, se recupera sem nenhuma sequela.
#
# No entanto, 15% das pessoas terão infecções graves e precisarão de oxigênio. O restante das pessoas, que representam 5%, serão classificadas como infecções muito graves e precisarão de ventilação assistida, por meio de respiradores mecânicos em ambiente hospitalar.
#
# Com o objetivo de elevar a consciência situacional a respeito do COVID-19 no Brasil, irei realizar uma análise sobre os dados públicos da doença.

# %% [markdown]
# ## Obtenção dos Dados
#
# Os dados usados estão disponíveis no site Our World Tour. O número de casos são atualizados todos os dias e os números de vacinação atualizados semanalmente.
#
# O site Our World Data é uma iniciativa de vários cientistas para compartilhamento de dados de interesse mundial. Lá é possível encontrar dados referentes a diferentes áreas, seja dados relacionados à saúde, geografia e política.
#
# Em maio de 2022 houve uma flexibilização para o uso de máscaras no estado de São Paulo. Nessa data o uso obrigatório de máscaras ficou restrito a apenas hospitais e unidades de saúde, transportes públicos, estações de trens, de  ônibus e de metrôs. Agora, em Setembro, uma nova atualização das medidas aumentou a flexibilização para a obrigatoriedade de máscaras apenas para hospitais e unidades de saúde.
#
# A partir dessas informações, vem a ideia de verificar como estão os dados de COVID atualmente no Brasil e no mundo e como está avançando a vacinação.
#
#
# ### Dicionário de Variáveis
#
# De acordo com o Our World Data eles dividem os casos em categorias de: **casos confirmados, mortes, mortes acumuladas, hospitalizações, políticas públicas realizadas, taxa de reprodução do vírus, testes de detecção, vacinação e outros.**
#
# Variáveis sobre os casos confirmados:
#
# * **total_cases -** Total de casos confirmados. Nestes dados podem estar incluídos casos suspetso que foram reportados.
# * **new_cases -**	Numéro de novos casos.
# * **new_cases_smoothed -** Número de novos casos (suavizados em 7 dias).
# * **total_cases_per_million -** Total de casos confirmados por milhão de habitantes.
# * **new_cases_per_million -** Novos casos por milhão de habitantes.
# * **new_cases_smoothed_per_million -**  Novos casos por milhão de habitantes (suavizados em 7 dias)
#
# Variáveis relacionadas ao número de mortes:
#
# * **total_deaths -** Total de mortes pela COVID-19.
# * **new_deaths -**	Novas mortes atribuídas a COVID-19
# * **new_deaths_smoothed -** Novas mortes atribuídas a COVID-19 (suavizados em 7 dias)
# * **total_deaths_per_million -** 	Total de mortes atribuída a COVID-19 por milhão de habitantes.
# * **new_deaths_per_million -** Novas mortes atribuídas a COVID-19 por milhão de habitantes.
# * **new_deaths_smoothed_per_million -** Novas mortes atribuídas a COVID-19 (suavizados em 7 dias) por milhão de habitantes.
#
# Mortalidade de excesso:
#
# * **excess_mortality -** Diferença em percentual do número de mortes reportados semanalmente ou mensalmente no período de 2020 - 2021 e o número de mortes projetados para o mesmo período baseados no ano anterior.
# * **excess_mortality_cumulative -** Diferença em percentual do número de mortes desde 1 de janeiro de 2020 e o número acumulado de mortes projetadas para o mesmo período  baseados no ano anterior.
# * **excess_mortality_cumulative_absolute -** Diferença acumulado entre o número de mortes reportados desde 1 de janeiro de 2020 e o número acumulado de mortes projetados para o mesmo período baseados no ano anterior.
# * **excess_mortality_cumulative_per_million -**   Diferença acumulado entre o número de mortes reportados desde 1 de janeiro de 2020 e o número acumulado de mortes projetados para o mesmo período baseados no ano anterior por milhão de habitantes.
#
# Hospitalizações:
#
# * **icu_patients -** Número de pacientes em unidades de tratamentos intensivas (UTIs) para o dia determinado.
# * **icu_patients_per_million -** Número de pacientes em  UTIs para o dia determinado por milhão de habitantes.
# * **hosp_patients -** Número de pacientes hospitalizados com COVID-19 para o determinado dia.
# * **hosp_patients_per_milliom -** Número de pacientes hospitalizados com COVID-19 para o determinado dia por milhão de habitantes.
# * **weekly_icu_admissions -** Número de pacientes com COVID-19 recém admitidos em UTIs na determinada semana (a data de notificação é de 6 dias antes)
# * **weekly_icu_admissions_per_million -** Número de pacientes com COVID-19 recém admitidos em UTIs na determinada semana (a data de notificação é de 6 dias antes) por milhão de habitantes.
# * **weekly_hosp_admissions -** Número de pacientes com COVID-19 recém admitidos em hospitais em uma determinada semana.
# * **weekly_hosp_admissions_per_million -**  Número de pacientes com COVID-19 recém admitidos em hospitais em uma determinada semana por milhão de habitantes.
#
# Políticas adotadas:
#
# * **strigency_index -** Índice de rigidez de resposta do governo: esta medida é composta por 9 indicadores de resposta, em que inclui fechamento de escolas,  fechamento de locais de trabalho e proibição de viagens. O valor tem escala de 0 a 100 (para 100 a resposta mais rígida).
#
# Taxa de reprodução do vírus:
#
# * **reproduction_rate -** estimativa em tempo real da taxa de reprodução da COVID-19.
#
# Testes de Covid:
#
# * Em junho de 2022 foi encerrada a atualização de dados para esta variável.
#
# Vacinação:
#
#
# * **total_vaccinations -** Total de doses de vacinação contra COVID-19 administradas.
# * **people_vaccinated -** Número total de pessoas que receberam pelo menos uma dose da vacina.
# * **people_fully_vaccvinated -** Número total de pessoas que receberam todas as doses disponíveis da vacina.
# * **total_boosters -**  Número total de doses de reforço administradas.
# * **new_vaccinations -** Novas doses de vacinação contra COVID-19 administradas.
# * **new_vaccinations_smoothed -** Novas doses de COVID-19 administradas (suavizadas por 7 dias). Nos países que não relatam os dados diários de vacinação, assume-se que a vacinação ocorreu igualmente em todos os períodos em que nenhum dado foi relatado. Assim é feito uma série completa de números diários que são calculados em um intervalo contínuo de 7 dias.
# * **total_vaccinations_per_hundred -** Número total de doses de vacinação para COVID-19 administradas por 100 habitantes.
# * **people_vaccinated_per_hundred-** Número total de pessoas que se vacinarem com pelo menos uma dose de vacina por 100 habitantes.
# * **people_fully_vaccinated_per_hundred -** Número total de pessoas com vacinação completa de doses disponíveis por 100 habitantes.
# * **total_boosters_per_hundred -** Número total de doses reforço administradas por 100 habitantes.
# * **new_vaccinations_smoothed_per_million -** Novas doses de vacinas para COVID-19 administradas (suavizados em 7 dias) por 100 habitantes.
# * **new_people_vaccinated_smoothed -** Número diário de pessoas que recebem a primeira dose da vacina (suavizados em 7 dias)
# * **new_people_vaccinated_smoothed_per_hundred -** Número diário de pessoas que recebem a primeira dose da vacina (suavizadao em 7 dias) por 100 habitantes.
#
# Outras variáveis:
#
# * **iso_code -**  ISO 3166-1 alpha-3  códigos de país de três letras. Observe que as regiões definidas pelo OWID (por exemplo, continentes como 'Europa') contém o prefixo 'OWID'.
# * **continent -**  Continente da localização geográfica
# * **location -**  Localização geográfica. A localização 'Internacional' considera regiões especiais (cruzeiros "Diamond Princess" e "MS Zaandam").
# * **date-** Data da observação
# * **population -** População.
# * **population_density -** Número de pessoas dividido por área de terra, medido em quilômetros quadrados, ano mais recente disponível.
# * **median_age -**  Idade média da população, projeção da ONU para 2020
# * **age_65_older -** Parcela da população com 65 anos ou mais, ano mais recente disponível
# * **age_70_older -** Parcela da população com 70 anos ou mais em 2015
# * **gdp_per_capita -** Produto interno bruto em paridade de poder de compra (dólares internacionais constantes de 2011), ano mais recente disponível
# * **extreme_poverty -**  Percentual da população que vive em extrema pobreza, ano mais recente disponível desde 2010
# * **cardiovasc_death_rate -** Taxa de mortalidade por doença cardiovascular em 2017 (número anual de mortes por 100.000 pessoas)
# diabetes_prevalence - Prevalência de diabetes (% da população de 20 a 79 anos) em 2017
# * **female_smokers -** Proporção de mulheres que fumam, ano mais recente disponível
# * **male_smokers -**  Proporção de homens que fumam, ano mais recente disponível
# * **handwashing_facilities -** Proporção da população com instalações básicas de lavagem das mãos nas instalações, ano mais recente disponível
# * **hospital_beds_per_thousand -**  Camas hospitalares por 1.000 pessoas, ano mais recente disponível desde 2010
# * **life_expectancy -**  Expectativa de vida ao nascer em 2019
# * **human_development_index -** Um índice composto que mede o desempenho médio em três dimensões básicas do desenvolvimento humano – uma vida longa e saudável, conhecimento e um padrão de vida decente.

# %% [markdown]
# ### Importando os dados do COVID-19

# %%
# importar as bibliotecas necessárias
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np


sns.set_theme(style="whitegrid", palette = "mako")
# %matplotlib inline

# importar o dataset COVID-19 para um DataaFrame
DATA_PATH = 'https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/owid-covid-data.csv'

df = pd.read_csv(DATA_PATH)

# %% [markdown]
# ## Análise Exploratória dos Dados
#
# A COVID 19 foi considerada pandemia pela OMS em Março de 2020. A partir daí, com ajuda da OMS e outros cientistas, os países estabeleceram algumas diretrizes para mitigar o contágio do vírus. As maiores flexibilizações dessas diretrizes ocorreram no ano de 2022. Essas flexibilizações só foi possível com o alto número de pessoas vacinadas.
#
# Nesta análise será mostrada alguns dados atualizados sobre a COVID 19 no mundo e no Brasil . Esses dados são os números de casos, óbitos  e vacinação.
#
#
# ### Análise Exploratória Inicial

# %%
# Visualização das 5 primeiras entredas dos dados
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# ...

# %% [markdown]
# Veremos o volume dos dados.

# %%
# identificar o volume dos dados
print(f'Neste dateframe há {df.shape[1]} variáveis e {df.shape[0]} entradas.')
# Out:
# Neste dateframe há 67 variáveis e 219867 entradas.

# %% [markdown]
# Vamos observar o nome de todas as variáveis que estão neste dataset.

# %%
#nome das colunas
print('As variáveis nesse dateset são:\n')
df.columns
# Out:
# As variáveis nesse dateset são:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
# ...

# %% [markdown]
# Por questões práticas quando se tem em um conjuntos de dados entradas que se referem a datas é sempre bom defini-las para o modo datetime. Assim selecionar algumas linhas a partir da data referida.

# %%
# Transformando a coluna date no formato datetime
df.date = pd.to_datetime(df.date)

# %% [markdown]
# Uma das etapas da análise exploratória, de importante realização, é verificar os valores ausentes. É interessante que essa visualização seja feita em porcentagem dos valores porque assim temos uma ideia de quão importante essa falta de entradas é em relação ao conjunto dos dados.

# %%
print('As variáveis que possuem mais valores ausentes, em porcentagem (%), são:\n')
(df.isnull().sum()/df.shape[0]*100).sort_values(ascending=False)
# Out:
# As variáveis que possuem mais valores ausentes, em porcentagem (%), são:
# weekly_icu_admissions_per_million          96.766682
# weekly_icu_admissions                      96.766682
# excess_mortality_cumulative_per_million    96.607040
# excess_mortality_cumulative                96.607040
# excess_mortality_cumulative_absolute       96.607040
#                                              ...
# total_cases                                 4.071552
# population                                  0.583080
# date                                        0.000000
# location                                    0.000000
# iso_code                                    0.000000
# Length: 67, dtype: float64

# %% [markdown]
# ### Análise

# %% [markdown]
# O destaque agora será para entradas específicas. De acordo com a data atual da realização dessa análise, veremos os países que possuem o maior número de mortos pela COVID 19, o maior número de casos e o país com mais pessoas vacinadas.

# %%
# ver dados nas datas atuais
df.loc[df.date == '2022-09-26'].sort_values(by="total_cases", ascending= False)
# Out:
#         iso_code continent        location       date  total_cases  new_cases  \
# 217114  OWID_WRL       NaN           World 2022-09-26  615465127.0   463574.0
# 86501   OWID_HIC       NaN     High income 2022-09-26  379535114.0   388234.0
# 64374   OWID_EUR       NaN          Europe 2022-09-26  228053198.0   251859.0
# 11389   OWID_ASI       NaN            Asia 2022-09-26  184823354.0   133542.0
# 65354   OWID_EUN       NaN  European Union 2022-09-26  166959600.0   208591.0
# ...          ...       ...             ...        ...          ...        ...
# 93176   OWID_INT       NaN   International 2022-09-26        721.0        0.0
# 213513       VAT    Europe         Vatican 2022-09-26         29.0        0.0
# 203441       TUV   Oceania          Tuvalu 2022-09-26         20.0        0.0
# 165879       SHN    Africa    Saint Helena 2022-09-26          7.0        0.0
# 146438       PRK      Asia     North Korea 2022-09-26          1.0        0.0
#
# ...

# %% [markdown]
# Com a tabela acima verificamos que as entradas para a variável localização inclui também o total mundial e uma separação por regiões. Porém, também observamos que para essas entradas a variável *continent* possui valores vazios.
#
# Vamos observar o número de casos totais no mundo atualmente. Após deletamos os valores vazios na variável *continent* para que assim vermos as entradas apenas por países da variável location.

# %%
world = df.loc[(df.date == '2022-09-26') & (df.location == 'World')]

world[['total_cases', 'people_vaccinated', 'people_fully_vaccinated', 'total_deaths']]
# Out:
#         total_cases  people_vaccinated  people_fully_vaccinated  total_deaths
# 217114  615465127.0       5.378544e+09             4.947919e+09     6538137.0

# %% [markdown]
# Até a data de 26 de Setembro de 2022 houve no mundo aproximadamente 615 milhões de casos de COVID-19. Pelo menos aproximadamente 5,37 bilhões de pessoas já tomaram pelo menos uma dose da vacina e 4,9 bilhões de pessoas estão com todas as doses da vacina disponíveis. No mundo houve aproximadamente 6,5 milhões de pessoas que morreram devido a COVID-19

# %% [markdown]
# Vamos observar os dados agora separados por países.
#
# Como será realizada uma modificação nos dados é sempre bom realizar um ponto de retorno.

# %%
# realizando um ponto de retorno
df_countries = df.copy()

# %%
df_countries = df_countries.dropna(subset=['continent'])

# %% [markdown]
# Vamos selecionar os dados e plotar um gráfico de barras para melhor visualizarmos os países com o maior número de casos até o dia 26 de Setembro de 2022.

# %%
df_countries_max_actual = df_countries[['location','total_cases', 'people_vaccinated', 'people_fully_vaccinated', 'total_deaths']].loc[df_countries.date == '2022-09-26'].sort_values(by="total_cases", ascending= False).iloc[:5,]
fig, ax = plt.subplots(figsize=(9,4.5))
ax = sns.barplot(x=df_countries_max_actual.location, y = df_countries_max_actual.total_cases)

ax.set_title('Os 5 países com o maior número de casos de COVID-19', loc = 'left', fontsize=14)
ax.set_xlabel('Países', fontsize = 12)
ax.set_ylabel('Número total de casos', fontsize = 12)
plt.ticklabel_format(style='plain', axis='y')
sns.despine()
fig.tight_layout()
plt.show()

# %% [markdown]
# Da mesma forma veremos os países que tiveram o maior número de mortes devido a COVID-19.

# %%
df_countries_max_actual = df_countries[['location','total_cases', 'total_vaccinations', 'total_deaths']].loc[df_countries.date == '2022-09-26'].sort_values(by="total_deaths", ascending= False).iloc[:5,]


fig, ax = plt.subplots(figsize=(9,4.5))
ax = sns.barplot(x=df_countries_max_actual.location, y = df_countries_max_actual.total_deaths)

ax.set_title('Os 5 países com o maior número de mortes por COVID-19', loc = 'left', fontsize=14)
ax.set_xlabel('Países', fontsize = 12)
ax.set_ylabel('Número total de mortes', fontsize = 12)
plt.ticklabel_format(style='plain', axis='y')
sns.despine()
fig.tight_layout()
plt.show()

# %% [markdown]
# Olhemos então para os países com o maior número de casos como está o número de casos diários.

# %%
df_countries_max_cases = df_countries[['location','new_cases_smoothed', 'total_cases', 'date']].sort_values(by="total_cases", ascending= False).loc[df_countries['location'].isin(['United States', 'India', 'France', 'Brazil', 'Germany'])]

sns.set_theme(style='white')
fix, ax = plt.subplots(figsize=(14,7))
ax = sns.lineplot(x= 'date', y = 'new_cases_smoothed', data = df_countries_max_cases, hue='location')
ax.legend(frameon=False, bbox_to_anchor=(1,1), title = 'Países', labels=['Estados Unidos',
                                                                         'India', 
                                                                         'França',
                                                                         'Brasil','Alemanha'])
ax.set_title('Número de novos casos semanais', loc = 'left', fontsize = 18)
ax.set_ylabel('Núemro de casos', fontsize = 14)
ax.set_xlabel('Datas', fontsize = 14)
sns.despine()

# %% [markdown]
# É visto que nesses países houve uma diminuição no número de casos. Principalmente a Índia que hoje possui o menor número de casos semanais. Houve um pico grande de casos nos Estados Unidos ainda em 2022, porém ainda no primeiro semestre do ano houve uma queda nesses casos.

# %% [markdown]
# ## Dados COVID-19 do Brasil

# %% [markdown]
# Os dados sobre a COVID-19 no Brasil foram obtidos no site: https://covid.saude.gov.br/. Site administrado pelo Ministério da Saúde.

# %%
df_brazil = pd.read_csv("covid_brazil.csv", sep=';')
df_brazil.head()
# Out:
#    regiao estado municipio  coduf  codmun  codRegiaoSaude nomeRegiaoSaude  \
# 0  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 1  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 2  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 3  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 4  Brasil    NaN       NaN     76     NaN             NaN             NaN
#
#          data  semanaEpi  populacaoTCU2019  casosAcumulado  casosNovos  \
# 0  2021-07-01         26       210147125.0      18622304.0       65163
# 1  2021-07-02         26       210147125.0      18687469.0       65165
# 2  2021-07-03         26       210147125.0      18742025.0       54556
# 3  2021-07-04         27       210147125.0      18769808.0       27783
# 4  2021-07-05         27       210147125.0      18792511.0       22703
#
#    obitosAcumulado  obitosNovos  Recuperadosnovos  emAcompanhamentoNovos  \
# ...

# %%
df_brazil.columns
# Out:
# Index(['regiao', 'estado', 'municipio', 'coduf', 'codmun', 'codRegiaoSaude',
#        'nomeRegiaoSaude', 'data', 'semanaEpi', 'populacaoTCU2019',
#        'casosAcumulado', 'casosNovos', 'obitosAcumulado', 'obitosNovos',
#        'Recuperadosnovos', 'emAcompanhamentoNovos', 'interior/metropolitana'],
#       dtype='object')

# %%
# identificando o volume dos dados da COVID-19 no Brasil
print(f'Nesete dateframe há {df_brazil.shape[1]} variáveis e {df_brazil.shape[0]} entradas.')
# Out:
# Nesete dateframe há 17 variáveis e 5125666 entradas.

# %% [markdown]
# Nestes dados há uma variável que corresponde a data. É legal convertê-la para modo datetime para ficar melhor no trabalho.

# %%
df_brazil.data = pd.to_datetime(df_brazil.data)

# %% [markdown]
# Realizando uma análise exploratório parecida com a feita aos dados mundiais, vamos verificar como está o número de casos no Brasil na última data dos dados (26/09/2022)

# %%
df_brazil[['casosAcumulado', 'casosNovos', 'obitosAcumulado', 'obitosNovos']].loc[(df_brazil.data == "2022-09-26") & (df_brazil.regiao == "Brasil")]
# Out:
#          casosAcumulado  casosNovos  obitosAcumulado  obitosNovos
# 4632337      34638288.0        6068           685835           30

# %% [markdown]
# Na data de 26 de Setembro houve 6068 novos casos de COVID-19 no Brasil, totalizando aproximadamente 34 milhões de casos até então. Nesta data também houve 30 óbitos em decorrência da COVID-19 totalizando aproximados 685 mil óbitos.

# %% [markdown]
# Continuemos a observar a data 26 de Setembro.

# %%
df_brazil_act = df_brazil.loc[df_brazil.data == '2022-09-26']

# %% [markdown]
# Observemos agora os valores mais especificamente por região e estado. Para isso vamos deletar a primeira linha que corresponde aos dados do Brasil todo.

# %%
df_brazil_act = df_brazil_act.iloc[1: , :]

# %%
df_brazil_act.head()
# Out:
#         regiao estado municipio  coduf  codmun  codRegiaoSaude  \
# 4632425  Norte     RO       NaN     11     NaN             NaN
# 4632513  Norte     AC       NaN     12     NaN             NaN
# 4632601  Norte     AM       NaN     13     NaN             NaN
# 4632689  Norte     RR       NaN     14     NaN             NaN
# 4632777  Norte     PA       NaN     15     NaN             NaN
#
#         nomeRegiaoSaude       data  semanaEpi  populacaoTCU2019  \
# 4632425             NaN 2022-09-26         39         1777225.0
# 4632513             NaN 2022-09-26         39          881935.0
# 4632601             NaN 2022-09-26         39         4144597.0
# 4632689             NaN 2022-09-26         39          605761.0
# 4632777             NaN 2022-09-26         39         8602865.0
#
#          casosAcumulado  casosNovos  obitosAcumulado  obitosNovos  \
# 4632425        456375.0           0             7355            0
# ...

# %%
print(df_brazil_act['regiao'].unique())
# Out:
# ['Norte' 'Nordeste' 'Sudeste' 'Sul' 'Centro-Oeste']

# %% [markdown]
# Neste dataframe os dados estão separados por região do Brasil.
#
# Será separado dados para cada região. E primeiro olharemos como está o número de casos para cada região.

# %%
print(df_brazil_act.loc[df_brazil_act['regiao'] == 'Norte', 'casosAcumulado'].sum())
print(df_brazil_act.loc[df_brazil_act['regiao'] == 'Nordeste', 'casosAcumulado'].sum())
print(df_brazil_act.loc[df_brazil_act['regiao'] == 'Sudeste', 'casosAcumulado'].sum())
print(df_brazil_act.loc[df_brazil_act['regiao'] == 'Sul', 'casosAcumulado'].sum())
print(df_brazil_act.loc[df_brazil_act['regiao'] == 'Centro-Oeste', 'casosAcumulado'].sum())
# Out:
# 5141368.0
# 13768044.0
# 27383738.0
# 14707354.0
# 7899288.0

# %%
df_brazil_regiao = { 'regiao': ['Norte', 'Nordeste', 'Sudeste', 'Sul', 'Centro-Oeste'],
                   'casosAcumulado':[5141368.0, 13768044.0, 27383738.0, 14707354.0, 7899288.0]}

df_brazil_regiao = pd.DataFrame(df_brazil_regiao)

df_brazil_regiao = df_brazil_regiao.sort_values(by="casosAcumulado", ascending= False)

df_brazil_regiao.head()
# Out:
#          regiao  casosAcumulado
# 2       Sudeste      27383738.0
# 3           Sul      14707354.0
# 1      Nordeste      13768044.0
# 4  Centro-Oeste       7899288.0
# 0         Norte       5141368.0

# %%
fig, ax = plt.subplots(figsize=(9,4.5))
ax = sns.barplot(x=df_brazil_regiao.regiao, y = df_brazil_regiao.casosAcumulado)

fig.suptitle('Número de casos por região do Brasil', fontsize=14, x = 0.349, y = 0.95)
ax.set_title('Data: 26-09-2022', loc = 'left')
ax.set_xlabel('Regiões', fontsize = 12)
ax.set_ylabel('Número total de casos', fontsize = 12)
plt.ticklabel_format(style='plain', axis='y')
sns.despine()
fig.tight_layout()
plt.show()

# %% [markdown]
# É visto que o Sudeste é a região do Brasil que teve o maior número de casos. Porém, deve-se considerar que o sudeste também é a região com a maior população do país.

# %% [markdown]
# Assim, vamos analisar com mais detalhes esta região. Será então selecionado um novo data frame para essa região. Antes vamos observar como está o número de novos casos para essas regiões.

# %%
df_sudeste_act = df_brazil_act.loc[df_brazil_act['regiao'] == 'Sudeste'].sort_values(by="casosAcumulado", ascending= False).iloc[:4,]


fig, ax = plt.subplots(figsize=(9,4.5))

sns.set_theme(style="whitegrid", palette = "mako")
ax = sns.barplot(x=df_sudeste_act.estado, y = df_sudeste_act.casosAcumulado, ci = None)

fig.suptitle('Número de casos da região Sudeste', fontsize=14, x = 0.31, y = 0.95)
ax.set_title('Data: 26-09-2022', loc = 'left')
ax.set_xlabel('Estados', fontsize = 12)
ax.set_ylabel('Número total de casos', fontsize = 12)
plt.ticklabel_format(style='plain', axis='y')
sns.despine()
fig.tight_layout()
plt.show()

# %% [markdown]
# Aqui vemos que São Paulo é o estado com o maior número de casos acumulados de COVID-19 da região sudeste do Brasil. Veremos agora como está o número de casos diários.

# %%
new_brazil_sudeste = df_brazil.loc[df_brazil['estado'].isin(['MG', 'ES', 'RJ', 'SP'])].sort_values(by="casosAcumulado", ascending= False)

# %%
new_brazil_sudeste = new_brazil_sudeste.loc[new_brazil_sudeste['municipio'].isna()]

# %%
new_brazil_sudeste.columns
# Out:
# Index(['regiao', 'estado', 'municipio', 'coduf', 'codmun', 'codRegiaoSaude',
#        'nomeRegiaoSaude', 'data', 'semanaEpi', 'populacaoTCU2019',
#        'casosAcumulado', 'casosNovos', 'obitosAcumulado', 'obitosNovos',
#        'Recuperadosnovos', 'emAcompanhamentoNovos', 'interior/metropolitana'],
#       dtype='object')

# %%
sns.set_theme(style='white', palette = "Paired")

fix, ax = plt.subplots(figsize=(14,7))
ax = sns.lineplot(x= 'data', y = 'casosNovos', data = new_brazil_sudeste, hue='estado')

ax.legend(frameon=False, bbox_to_anchor=(1,1), title = 'Países', labels=['São Paulo',
                                                                        'Minas Gerais', 
                                                                        'Rio de Janeiro',
                                                                      'Espírito Santo'])
ax.set_title('Número de novos casos', loc = 'left', fontsize = 18)
ax.set_ylabel('Núemro de casos', fontsize = 14)
ax.set_xlabel('Datas', fontsize = 14)
sns.despine()

# %% [markdown]
# É visto que o número de novos casos está baixo para esse semestre de 2022. Infelizmente não há nos dados uma divisão semanal que deixaria a curva no gráfico mais suave podendo visualizar melhor o comportamento no número de casos.

# %% [markdown]
# ## Conclusões

# %% [markdown]
# Este projeto analisou os dados da Covid-19 para a data de 26 de Setembro de 2019. O projeto teve o objetivo de demosntrar como é realizado uma análise de dados extensos e a importância de fazer análise. Os dados aqui analisados foram disponibilizados pela Our World data e pelo Ministério da Saúd do Brasil. Foi possível concluir alguns pontos:
#
# Os dados para da covid- 19 tinham o continham 67 variáveis e 219867 entradas.
#
# Até a data de 26 de Setembro de 2022 houve no mundo aproximadamente:
# * 616 milhões de casos de COVID-19.
# * 5,38 bilhões de pessoas já tomaram pelo menos uma dose da vacina.
# * 4,9 bilhões de pessoas estão com todas as doses da vacina disponíveis.
# * 6,5 milhões de pessoas que morreram devido a COVID-19
# * Os 5 países com os maiores números de casos são: Estados Unidos, Índia, França, Brasil e Alemanha, respectivamente.
# * Os 5 países com os maiores números de óbitos devido a COVID-19 são Estados Unidos, Brasil, Índia, Rússia e México.
# * Os Estados Unidos é o país com o maior número de casos e também o país com mais mortes.
# * No Brasil, a região Sudeste foi a que teve o maior número de casos, sendo São Paulo com o maior número de casos nesta região.
# * E houve até o dia 26 de Setembro de 2022 34 milhões de casos de Covid-19.
